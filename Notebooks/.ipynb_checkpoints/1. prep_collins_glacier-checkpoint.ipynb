# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df_met = pd.read_csv('../data/xls_Bulath/Bullath_metadata.csv',sep = '\t')
df_smb      = pd.read_excel('../data/xls_Bulath/Bullath_all.xls', header=None)
smb_data    = df_smb.values[:,1:-1]
smb_time    = df_smb.values[:,0]

# %%
df_smb.columns = df_met.Name_orig

# %%
smb_coll = []
for i in df_met.Name_orig[1:3]:
    subset = (df_smb[['Date', i]])
    subset.rename(columns = {i:'SMB'},  inplace=True)
    subset['Stake'] = i
    g_met = df_met.loc[lambda df_met: df_met['Name_orig'] == i, :]
    subset['Latitude']  = float(g_met.Latitude.values)
    subset['Longitude'] = float(g_met.Longitude.values)
    subset['Elevation'] = float(g_met.Elevation.values)
    subset.dropna(inplace=True)
    date_2 = []
    date_2.append(subset.Date[subset.index[0]])
    for j in subset.Date[0:-1]:
        date_2.append(j)

    smb_2 = []
    smb_2.append(0)
    for j in subset.SMB[0:-1]:
        smb_2.append(j)

    subset['Date1'] = date_2
    subset['SMB1'] = smb_2
    subset['Days'] = (subset['Date'] - subset['Date1']).dt.days
    subset['SMB_diff'] = -(subset['SMB1'] - subset['SMB'])
    subset = subset[['Stake', 'Date', 'Date1','Latitude', 'Longitude',
                     'Elevation', 'Days', 'SMB', 'SMB1', 'SMB_diff']]
    smb_coll.append(subset)

# %%
smb_coll_df = pd.concat(smb_coll, ignore_index=True)
smb_coll_df[['SMB_diff', 'SMB']] = smb_coll_df[['SMB_diff', 'SMB']]/100

# %%
smb_coll_df[0:25]
# Out:
# Name_orig Stake       Date      Date1  Latitude  Longitude  Elevation  Days  \
# 0            R1 2007-11-08 2007-11-08 -62.17762 -58.902406       82.0     0
# 1            R1 2007-12-09 2007-11-08 -62.17762 -58.902406       82.0    31
# 2            R1 2007-12-18 2007-12-09 -62.17762 -58.902406       82.0     9
# 3            R1 2007-12-26 2007-12-18 -62.17762 -58.902406       82.0     8
# 4            R1 2008-01-05 2007-12-26 -62.17762 -58.902406       82.0    10
# 5            R1 2008-01-12 2008-01-05 -62.17762 -58.902406       82.0     7
# 6            R1 2008-01-19 2008-01-12 -62.17762 -58.902406       82.0     7
# 7            R1 2008-01-26 2008-01-19 -62.17762 -58.902406       82.0     7
# 8            R1 2008-02-02 2008-01-26 -62.17762 -58.902406       82.0     7
# 9            R1 2008-02-09 2008-02-02 -62.17762 -58.902406       82.0     7
# 10           R1 2008-02-13 2008-02-09 -62.17762 -58.902406       82.0     4
# 11           R1 2008-02-16 2008-02-13 -62.17762 -58.902406       82.0     3
# 12           R1 2008-02-24 2008-02-16 -62.17762 -58.902406       82.0     8
# 13           R1 2008-03-02 2008-02-24 -62.17762 -58.902406       82.0     7
# 14           R1 2008-03-07 2008-03-02 -62.17762 -58.902406       82.0     5
# 15           R1 2008-03-09 2008-03-07 -62.17762 -58.902406       82.0     2
# 16           R1 2008-03-17 2008-03-09 -62.17762 -58.902406       82.0     8
# 17           R1 2008-11-03 2008-03-17 -62.17762 -58.902406       82.0   231
# 18           R1 2008-11-13 2008-11-03 -62.17762 -58.902406       82.0    10
# 19           R1 2008-11-21 2008-11-13 -62.17762 -58.902406       82.0     8
# 20           R1 2008-11-28 2008-11-21 -62.17762 -58.902406       82.0     7
# 21           R1 2008-12-05 2008-11-28 -62.17762 -58.902406       82.0     7
# 22           R1 2008-12-09 2008-12-05 -62.17762 -58.902406       82.0     4
# 23           R1 2008-12-13 2008-12-09 -62.17762 -58.902406       82.0     4
# 24           R1 2008-12-19 2008-12-13 -62.17762 -58.902406       82.0     6
#
# Name_orig      SMB    SMB1  SMB_diff
# 0          0.68800  68.800  -0.00000
# 1          0.75840  68.800   0.07040
# 2          0.73730  75.840  -0.02110
# 3          0.65472  73.730  -0.08258
# 4          0.44000  65.472  -0.21472
# 5          0.48209  44.000   0.04209
# 6          0.38688  48.209  -0.09521
# 7          0.18340  38.688  -0.20348
# 8          0.09842  18.340  -0.08498
# 9          0.10692   9.842   0.00850
# 10         0.00000  10.692  -0.10692
# 11        -0.06400   0.000  -0.06400
# 12        -0.31400  -6.400  -0.25000
# 13        -0.44000 -31.400  -0.12600
# 14        -0.59300 -44.000  -0.15300
# 15        -0.62900 -59.300  -0.03600
# 16        -0.62900 -62.900  -0.00000
# 17         0.42312 -62.900   1.05212
# 18         0.42140  42.312  -0.00172
# 19         0.37520  42.140  -0.04620
# 20         0.27940  37.520  -0.09580
# 21         0.17501  27.940  -0.10439
# 22         0.13959  17.501  -0.03542
# 23         0.14100  13.959   0.00141
# 24         0.01028  14.100  -0.13072

# %%
smb_coll_df.to_csv('../data/SMB_bellin_diff.csv', index=False, sep='\t')

# %%
labels = smb_coll_df.drop_duplicates(subset=['Stake'])

# %%
cs_file = '../data/SMB_bellin_diff.csv'
dfmb = pd.read_csv(cs_file,
   delimiter='\t', index_col=['Date'],
    parse_dates=['Date'], na_values='NAN')
labels = dfmb.drop_duplicates(subset=['Stake'])

# %%
fig, ax1 = plt.subplots(1,1,figsize=(6,4))
ax2 = ax1.twinx()

for i in labels['Stake'][0:1]:
    stake = dfmb.loc[lambda df: df['Stake'] == i, :]
    ax2.plot(stake['SMB']['20071101':'20080430'], 'b-', linewidth=0.5)
    smb_b = stake['SMB_diff']['20071101':'20080430']
    ax1.bar(smb_b.index, smb_b.values)
    ax1.axhline(0, linewidth=1, color='grey', linestyle =':')
#    print(smb_b)
#    ax1.plot(stake['SMB_diff']['20071101':'20080430'], 'b-', kind='bar')

#ax1.legend(['SMB'], loc='best')
ax1.set_ylabel(u'Surface Mass Balance (m w.e.)')
#ax1.set_ylim(-1., 1.)

#ax2.legend(['Days'], loc='best')
#ax2.set_ylabel('Days')
ax2.set_ylim(-0.9, 0.9)
fig.autofmt_xdate()
#fig.savefig('../fig/data_stakes_bellin.png',dpi = 150, bbox_inches = 'tight', 
#             pad_inches = 0.1, facecolor='w')
