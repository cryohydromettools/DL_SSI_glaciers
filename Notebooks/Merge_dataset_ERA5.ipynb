# %%
import pandas as pd

# %%
data_inp_bell = pd.read_csv('../data/SMB_input_belli_sea_ERA5.csv', sep='\t')
data_inp_four = pd.read_csv('../data/SMB_input_four_sea_ERA5.csv', sep='\t')

# %%
data_all = pd.concat([data_inp_bell, data_inp_four])
data_all.to_csv('../data/SMB_input_all_ERA5_sea.csv', index=False, sep='\t')

# %%
data_all
# Out:
#     Stake        Date   Latitude  Longitude  Elevation  Days      SMB  \
# 0     R15  2008-01-05 -62.178873 -58.907921       54.0   249  0.49203
# 1     R15  2008-03-11 -62.178873 -58.907921       54.0    66 -0.46800
# 2     R15  2009-01-24 -62.178873 -58.907921       54.0   319  0.00000
# 3     R15  2009-03-01 -62.178873 -58.907921       54.0    36 -0.66600
# 4     R15  2009-12-13 -62.178873 -58.907921       54.0   287  1.77990
# ..    ...         ...        ...        ...        ...   ...      ...
# 114  PG05  2014-04-30 -62.227069 -58.598800      247.9   155 -0.03000
# 115  PG05  2014-11-30 -62.227069 -58.598800      247.9   214  1.27000
# 116  PG05  2015-04-13 -62.227069 -58.598800      247.9   134 -0.83000
# 117  PG05  2015-11-19 -62.227069 -58.598800      247.9   220  1.08000
# 118  PG05  2016-04-23 -62.227069 -58.598800      247.9   156 -1.22000
#
#           t2m         rh         u2        SWin       LWin        tp  \
# ...
