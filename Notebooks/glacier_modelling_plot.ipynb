# %%
import xarray as xr

# %%
cs_file = '../data/out/Belli_glacier_new.nc'
ds = xr.open_dataset(cs_file)

# %%
ds['Melt'][0].plot()

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lon: 17, lat: 12, time: 744)
# Coordinates:
#   * lon      (lon) float64 -58.94 -58.93 -58.93 -58.92 ... -58.85 -58.84 -58.83
#   * lat      (lat) float64 -62.19 -62.19 -62.18 -62.18 ... -62.15 -62.15 -62.14
#   * time     (time) datetime64[ns] 1959-01-31 1959-02-28 ... 2020-12-31
# Data variables:
#     HGT      (lat, lon) float64 47.73 28.86 65.03 58.98 ... 271.4 280.3 286.4
#     ASPECT   (lat, lon) float32 nan nan nan nan nan nan ... nan nan nan nan nan
#     SLOPE    (lat, lon) float32 nan nan nan nan nan nan ... nan nan nan nan nan
#     MASK     (lat, lon) float64 nan nan nan nan nan nan ... nan nan nan nan nan
#     T2       (time, lat, lon) float64 ...
#     Accu     (time, lat, lon) float64 ...
#     smb      (time, lat, lon) float64 ...
#     Melt     (time, lat, lon) float64 ...
#     Q        (time, lat, lon) float64 ...
#     MO       (time, lat, lon) float64 ...

# %%
df_gla = ds[['smb', 'Accu', 'Melt', 'Q']].mean(('lon', 'lat')).to_dataframe()

# %%
df_gla['smb'].plot()
# Out:
# <AxesSubplot:xlabel='time'>
